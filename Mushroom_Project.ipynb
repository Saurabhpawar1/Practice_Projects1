# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_excel("Mushroom.xlsx")
ds
# Out:
#      Class Cap shape Cap surface Cap color Bruises Odor Gill attachement  \
# 0        p         x           s         n       t    p                f
# 1        e         x           s         y       t    a                f
# 2        e         b           s         w       t    l                f
# 3        p         x           y         w       t    p                f
# 4        e         x           s         g       f    n                f
# ...    ...       ...         ...       ...     ...  ...              ...
# 8119     e         k           s         n       f    n                a
# 8120     e         x           s         n       f    n                a
# 8121     e         f           s         n       f    n                a
# 8122     p         k           y         n       f    y                f
# 8123     e         x           s         n       f    n                a
#
#      Gill spacing Gill size Gill color  ... Stalk surface below ring  \
# ...

# %%
sb.heatmap(ds.isnull(),annot=True)
plt.show()

# %%
ds.isnull().sum()
# Out:
# Class                       0
# Cap shape                   0
# Cap surface                 0
# Cap color                   0
# Bruises                     0
# Odor                        0
# Gill attachement            0
# Gill spacing                0
# Gill size                   0
# Gill color                  0
# Stalk shape                 0
# Stalk root                  0
# Stalk surface above ring    0
# Stalk surface below ring    0
# Stalk color above ring      0
# Stalk color below ring      0
# Veil type                   0
# Veil color                  0
# Ring number                 0
# Ring type                   0
# Spore print color           0
# Population                  0
# Habitat                     0
# dtype: int64

# %%
ds.dtypes
# Out:
# Class                       object
# Cap shape                   object
# Cap surface                 object
# Cap color                   object
# Bruises                     object
# Odor                        object
# Gill attachement            object
# Gill spacing                object
# Gill size                   object
# Gill color                  object
# Stalk shape                 object
# Stalk root                  object
# Stalk surface above ring    object
# Stalk surface below ring    object
# Stalk color above ring      object
# Stalk color below ring      object
# Veil type                   object
# Veil color                  object
# Ring number                 object
# Ring type                   object
# Spore print color           object
# Population                  object
# Habitat                     object
# dtype: object

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Class                     8124 non-null   object
#  1   Cap shape                 8124 non-null   object
#  2   Cap surface               8124 non-null   object
#  3   Cap color                 8124 non-null   object
#  4   Bruises                   8124 non-null   object
#  5   Odor                      8124 non-null   object
#  6   Gill attachement          8124 non-null   object
#  7   Gill spacing              8124 non-null   object
#  8   Gill size                 8124 non-null   object
#  9   Gill color                8124 non-null   object
#  10  Stalk shape               8124 non-null   object
#  11  Stalk root                8124 non-null   object
#  12  Stalk surface above ring  8124 non-null   object
# ...

# %%
ds.columns
# Out:
# Index(['Class', 'Cap shape', 'Cap surface', 'Cap color', 'Bruises', 'Odor',
#        'Gill attachement', 'Gill spacing', 'Gill size', 'Gill color',
#        'Stalk shape', 'Stalk root', 'Stalk surface above ring',
#        'Stalk surface below ring', 'Stalk color above ring',
#        'Stalk color below ring', 'Veil type', 'Veil color', 'Ring number',
#        'Ring type', 'Spore print color', 'Population', 'Habitat'],
#       dtype='object')

# %%
ds.describe()
# Out:
#        Class Cap shape Cap surface Cap color Bruises  Odor Gill attachement  \
# count   8124      8124        8124      8124    8124  8124             8124
# unique     2         6           4        10       2     9                2
# top        e         x           y         n       f     n                f
# freq    4208      3656        3244      2284    4748  3528             7914
#
#        Gill spacing Gill size Gill color  ... Stalk surface below ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        Stalk color above ring Stalk color below ring Veil type Veil color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

list1=['Class','Cap shape','Cap surface','Cap color','Bruises','Odor','Gill attachement','Gill spacing','Gill size','Gill color','Stalk shape','Stalk root','Stalk surface above ring','Stalk surface below ring','Stalk color above ring','Stalk color below ring','Veil type','Veil color','Ring number','Ring type','Spore print color','Population','Habitat']
for val in list1:
    ds[val]=le.fit_transform(ds[val].astype(str))

# %%
ds
# Out:
#       Class  Cap shape  Cap surface  Cap color  Bruises  Odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       Gill attachement  Gill spacing  Gill size  Gill color  ...  \
# 0                    1             0          1           6  ...
# 1                    1             0          0           6  ...
# ...

# %%
sb.pairplot(ds)

# %%
corr_hmap=ds.corr()
plt.figure(figsize=(8,7))
sb.heatmap(corr_hmap,annot=True)
plt.show()

# %%
ds['Spore print color'].plot.box()

# %%
ds['Class'].plot.hist()

# %%
plt.scatter(ds['Spore print color'],ds['Class'])

# %%
sb.lineplot(x=ds["Stalk color above ring"],y=ds["Class"],data=ds)
plt.show()

# %%
sb.lineplot(x=ds["Stalk color below ring"],y=ds["Class"],data=ds)
plt.show()

# %%
ds.skew()
# Out:
# Class                       0.071946
# Cap shape                  -0.247052
# Cap surface                -0.590859
# Cap color                   0.706965
# Bruises                     0.342750
# Odor                       -0.080790
# Gill attachement           -5.977076
# Gill spacing                1.840088
# Gill size                   0.825797
# Gill color                  0.078091
# Stalk shape                -0.271345
# Stalk root                  0.947852
# Stalk surface above ring   -1.098739
# Stalk surface below ring   -0.757703
# Stalk color above ring     -1.835434
# Stalk color below ring     -1.791593
# Veil type                   0.000000
# Veil color                 -6.946944
# Ring number                 2.701657
# Ring type                  -0.290018
# Spore print color           0.548426
# Population                 -1.413096
# Habitat                     0.985548
# dtype: float64

# %%
import numpy as np
for col in ds.columns:
    if ds.skew().loc[col]>0.55:
        ds[col]=np.log1p(ds[col])

# %%
ds.skew()
# Out:
# Class                       0.071946
# Cap shape                  -0.247052
# Cap surface                -0.590859
# Cap color                  -0.365280
# Bruises                     0.342750
# Odor                       -0.080790
# Gill attachement           -5.977076
# Gill spacing                1.840088
# Gill size                   0.825797
# Gill color                  0.078091
# Stalk shape                -0.271345
# Stalk root                  0.129453
# Stalk surface above ring   -1.098739
# Stalk surface below ring   -0.757703
# Stalk color above ring     -1.835434
# Stalk color below ring     -1.791593
# Veil type                   0.000000
# Veil color                 -6.946944
# Ring number                 1.481287
# Ring type                  -0.290018
# Spore print color           0.548426
# Population                 -1.413096
# Habitat                     0.342186
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
data = ds
print(power_transform(data, method='yeo-johnson'))
# Out:
# [[ 1.0366127   1.03577474  0.05017017 ... -0.53714841 -0.80052972
#    1.44021952]
#  [-0.96468045  1.03577474  0.05017017 ...  0.01906382 -1.47485647
#    0.19500801]
#  [-0.96468045 -2.02788189  0.05017017 ...  0.01906382 -1.47485647
#    1.0529549 ]
#  ...
#  [-0.96468045 -0.85127533  0.05017017 ... -2.80619461 -1.89857525
#    0.73356511]
#  [ 1.0366127  -0.23408877  0.99864626 ...  1.29862534  0.15412432
#    0.73356511]
#  [-0.96468045  1.03577474  0.05017017 ...  0.4401869  -1.89857525
#    0.73356511]]

# %%
ds.skew()
# Out:
# Class                       0.071946
# Cap shape                  -0.247052
# Cap surface                -0.590859
# Cap color                  -0.365280
# Bruises                     0.342750
# Odor                       -0.080790
# Gill attachement           -5.977076
# Gill spacing                1.840088
# Gill size                   0.825797
# Gill color                  0.078091
# Stalk shape                -0.271345
# Stalk root                  0.129453
# Stalk surface above ring   -1.098739
# Stalk surface below ring   -0.757703
# Stalk color above ring     -1.835434
# Stalk color below ring     -1.791593
# Veil type                   0.000000
# Veil color                 -6.946944
# Ring number                 1.481287
# Ring type                  -0.290018
# Spore print color           0.548426
# Population                 -1.413096
# Habitat                     0.342186
# dtype: float64

# %%
ds_x=ds.drop(columns=["Class"])
y=ds[["Class"]]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(ds_x)
x=pd.DataFrame(x,columns=ds_x.columns)

# %%
x
# Out:
#       Cap shape  Cap surface  Cap color   Bruises      Odor  Gill attachement  \
# 0      1.029712     0.140128   0.024326  1.185917  0.881938          0.162896
# 1      1.029712     0.140128   1.481371  1.185917 -1.970316          0.162896
# 2     -2.087047     0.140128   1.259896  1.185917 -0.544189          0.162896
# 3      1.029712     0.953270   1.259896  1.185917  0.881938          0.162896
# 4      1.029712     0.140128  -0.444738 -0.843230  0.406562          0.162896
# ...         ...          ...        ...       ...       ...               ...
# 8119  -0.216992     0.140128   0.024326 -0.843230  0.406562         -6.138869
# 8120   1.029712     0.140128   0.024326 -0.843230  0.406562         -6.138869
# 8121  -0.840343     0.140128   0.024326 -0.843230  0.406562         -6.138869
# 8122  -0.216992     0.953270   0.024326 -0.843230  1.832689          0.162896
# 8123   1.029712     0.140128   0.024326 -0.843230  0.406562         -6.138869
#
# ...

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=10)
xpca=pca.fit_transform(x)
x=xpca

# %%
pd.DataFrame(data=x)
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.725246 -0.950684 -1.047234  0.948852 -1.115064 -1.385011 -0.496789
# 1    -2.322217 -0.166049 -0.914639  1.229601 -1.521033 -1.274170 -0.917005
# 2    -1.843485 -0.399124 -0.857417  2.018440 -1.664106 -0.630403  1.480578
# 3    -0.934926 -0.836741 -1.028441  1.165545 -1.613404 -1.943631 -0.569085
# 4     0.290722  1.668172 -2.446591  1.629711  1.547704 -0.567785  0.219772
# ...        ...       ...       ...       ...       ...       ...       ...
# 8119 -0.788241 -0.624747  5.047298  5.084572  2.694139 -1.091159  0.091393
# 8120 -0.992258 -1.454393  7.077880  5.462312  3.977936 -1.726388 -1.294347
# 8121 -1.200777 -0.596403  4.965376  5.212262  2.870006 -0.932184  0.460005
# 8122  3.804033 -0.609619  0.014573 -0.263569 -0.107521 -0.536530  0.150812
# 8123 -0.088127 -0.803497  4.973266  5.099929  2.718945 -1.030998 -0.900717
#
#              7         8         9
# ...

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
max_r_score=0
for r_state in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    classi=DecisionTreeClassifier()
    classi.fit(x_train,y_train)
    y_pred=classi.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to",final_r_state,"is",max_r_score)
# Out:
# max r2 score corresponding to 27 is 0.9926106806358908

# %%
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

model=[LogisticRegression(),GaussianNB(),SVC(),DecisionTreeClassifier()]

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('Accuracy score of',m,'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy score of LogisticRegression() is:
# 0.9150769230769231
# [[770  43]
#  [ 95 717]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       813
#            1       0.94      0.88      0.91       812
#
#     accuracy                           0.92      1625
#    macro avg       0.92      0.92      0.91      1625
# weighted avg       0.92      0.92      0.91      1625
#
#
#
# Accuracy score of GaussianNB() is:
# 0.9021538461538462
# [[777  36]
#  [123 689]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       813
#            1       0.95      0.85      0.90       812
#
#     accuracy                           0.90      1625
#    macro avg       0.91      0.90      0.90      1625
# weighted avg       0.91      0.90      0.90      1625
#
#
#
# Accuracy score of SVC() is:
# 0.9993846153846154
# [[812   1]
#  [  0 812]]
# ...

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(SVC(),x,y,cv=5,scoring="r2").mean()
# Out:
# 0.6148799568858643

# %%
svc=SVC(kernel='rbf')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.9993846153846154
# [[812   1]
#  [  0 812]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       813
#            1       1.00      1.00      1.00       812
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625

# %%
lg=LogisticRegression()
lg.fit(x_train,y_train)
lg.score(x_train,y_train)
predlg=lg.predict(x_test)
print(accuracy_score(y_test,predlg))
print(confusion_matrix(y_test,predlg))
print(classification_report(y_test,predlg))
# Out:
# 0.9150769230769231
# [[770  43]
#  [ 95 717]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       813
#            1       0.94      0.88      0.91       812
#
#     accuracy                           0.92      1625
#    macro avg       0.92      0.92      0.91      1625
# weighted avg       0.92      0.92      0.91      1625

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# %%
y_pred_prob=lg.predict_proba(x_test)[:,1]

# %%
y_pred_prob
# Out:
# array([0.02600089, 0.16063955, 0.07913976, ..., 0.01529347, 0.93332416,
#        0.88724442])

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , 0.00123001, 0.00123001,
#        0.00246002, 0.00246002, 0.00369004, 0.00369004, 0.00492005,
#        0.00492005, 0.00615006, 0.00615006, 0.00738007, 0.00738007,
#        0.00861009, 0.00861009, 0.0098401 , 0.0098401 , 0.01107011,
#        0.01107011, 0.01230012, 0.01230012, 0.01353014, 0.01353014,
#        0.01476015, 0.01476015, 0.01599016, 0.01599016, 0.01722017,
#        0.01722017, 0.01845018, 0.01845018, 0.0196802 , 0.0196802 ,
#        0.02214022, 0.02214022, 0.02337023, 0.02337023, 0.02460025,
#        0.02460025, 0.02583026, 0.02583026, 0.02706027, 0.02706027,
#        0.02829028, 0.02829028, 0.0295203 , 0.0295203 , 0.03075031,
#        0.03075031, 0.03198032, 0.03198032, 0.03321033, 0.03321033,
#        0.03444034, 0.03444034, 0.03567036, 0.03567036, 0.03813038,
#        0.03813038, 0.04182042, 0.04182042, 0.04305043, 0.04305043,
#        0.04428044, 0.04428044, 0.04551046, 0.04551046, 0.04797048,
# ...

# %%
tpr
# Out:
# array([0.        , 0.00123153, 0.06650246, 0.06650246, 0.13423645,
#        0.13423645, 0.24384236, 0.24384236, 0.26477833, 0.26477833,
#        0.29433498, 0.29433498, 0.33004926, 0.33004926, 0.37315271,
#        0.37315271, 0.40147783, 0.40147783, 0.4137931 , 0.4137931 ,
#        0.42364532, 0.42364532, 0.6046798 , 0.6046798 , 0.61083744,
#        0.61083744, 0.62438424, 0.62438424, 0.62931034, 0.62931034,
#        0.64408867, 0.64408867, 0.68719212, 0.68719212, 0.71305419,
#        0.71305419, 0.71674877, 0.71674877, 0.7179803 , 0.7179803 ,
#        0.73029557, 0.73029557, 0.73275862, 0.73275862, 0.75      ,
#        0.75      , 0.75862069, 0.75862069, 0.76847291, 0.76847291,
#        0.77093596, 0.77093596, 0.77463054, 0.77463054, 0.78325123,
#        0.78325123, 0.81527094, 0.81527094, 0.83497537, 0.83497537,
#        0.8362069 , 0.8362069 , 0.83866995, 0.83866995, 0.84359606,
#        0.84359606, 0.85344828, 0.85344828, 0.85591133, 0.85591133,
# ...

# %%
thresholds
# Out:
# array([1.99914775e+00, 9.99147750e-01, 9.96213444e-01, 9.96199056e-01,
#        9.93534704e-01, 9.93496011e-01, 9.87406528e-01, 9.87253201e-01,
#        9.85364097e-01, 9.85341700e-01, 9.83215324e-01, 9.83213347e-01,
#        9.80435526e-01, 9.80263859e-01, 9.77881427e-01, 9.77817033e-01,
#        9.74130100e-01, 9.74086867e-01, 9.72745211e-01, 9.72662913e-01,
#        9.71521183e-01, 9.70931688e-01, 9.42546832e-01, 9.42513878e-01,
#        9.41689101e-01, 9.40376230e-01, 9.37746100e-01, 9.37292625e-01,
#        9.36407432e-01, 9.35516054e-01, 9.33055252e-01, 9.32979414e-01,
#        9.20492792e-01, 9.19704058e-01, 9.08709462e-01, 9.07927680e-01,
#        9.06627063e-01, 9.06549441e-01, 9.06229130e-01, 9.05370222e-01,
#        9.01262976e-01, 9.00555713e-01, 8.98824826e-01, 8.97936624e-01,
#        8.86559445e-01, 8.86297831e-01, 8.77431513e-01, 8.76301530e-01,
#        8.70919289e-01, 8.70220082e-01, 8.65429418e-01, 8.65112692e-01,
# ...

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='LogisticRegression')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Logistic Regression')
plt.show()

# %%
auc_score=roc_auc_score(y_test,lg.predict(x_test))

# %%
print(auc_score)
# Out:
# 0.9150571986015428

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.9932307692307693
# [[809   4]
#  [  7 805]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       813
#            1       1.00      0.99      0.99       812
#
#     accuracy                           0.99      1625
#    macro avg       0.99      0.99      0.99      1625
# weighted avg       0.99      0.99      0.99      1625

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
p=dt.predict(x_test)
print(accuracy_score(y_test,p))
# Out:
# 0.9944615384615385

# %%
y_pred_prob=dt.predict_proba(x_test)[:,0]
tpr,fpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Decision tree classifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Decision Tree Classifier')
plt.show()
auc_score=roc_auc_score(y_test,dt.predict(x_test))
auc_score
# Out:
# 0.9944596428722908

# %%
from sklearn import svm

from sklearn.model_selection import GridSearchCV
ds=pd.read_excel("Mushroom.xlsx")
parameters={'kernel':('linear','rbf'),'C':[1,10]}
svc=svm.SVC()
clf=GridSearchCV(svc,parameters)
clf.fit(x_train,y_train)

sorted(clf.cv_results_.keys())
# Out:
# ['mean_fit_time',
#  'mean_score_time',
#  'mean_test_score',
#  'param_C',
#  'param_kernel',
#  'params',
#  'rank_test_score',
#  'split0_test_score',
#  'split1_test_score',
#  'split2_test_score',
#  'split3_test_score',
#  'split4_test_score',
#  'std_fit_time',
#  'std_score_time',
#  'std_test_score']

# %%
accuracy=clf.best_score_

# %%
accuracy
# Out:
# 1.0

# %%
print(clf.best_params_)
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
svc=svm.SVC(kernel='rbf',C=10)
svc.fit(x_train,y_train)
# Out:
# SVC(C=10)

# %%
def predicttest(testvalue):
    testvalue=testvalue.reshape(1,-1)
    t=svc.predict(testvalue)
    print(t)

# %%
testv=np.array([2.32221,1.166049,-0.914639,1.229601,1.521033,-1.274170,0.917005,0.649021,0.356925,-0.171904])
predicttest(testv)
# Out:
# [0]

# %%
import joblib
joblib.dump(svc,'svc_Mushroom.pkl')
# Out:
# ['svc_Mushroom.pkl']
